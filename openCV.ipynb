# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
image_path = '/content/NarutoCoverTankobon1.jpg'

# %%
#Read the image using cv2.imread()

# %%
img =cv2.imread(image_path)

# %%
#Check if the image was loaded successfully

# %%
if img is None:
    print(f"Error: Inage not found at {image_path}or unable to load")

# %%
print(f"Error: Inage not found at {image_path}or unable to load")
# Out:
# Error: Inage not found at /content/NarutoCoverTankobon1.jpgor unable to load

# %%
#Display the image using cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=250x391>
